# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Exercise 2: Create markdown cell with title of the notebook
#
# Create a markdown cell with the title Data Science Tools and Ecosystem using H1 style heading.
#
# # Data Science Tools and Ecosystem

# %% [markdown]
# Exercise 3 - Create a markdown cell for an introduction
#
# Introduction:
# In this notebook, we explore the fundamental tools and ecosystems that are essential for data science. By summarizing popular programming languages and libraries, we provide a foundational understanding of what data scientists use to analyze data, implement models, and generate insights.

# %% [markdown]
# Exercise 4 - Create a markdown cell to list data science languages
#
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# Exercise 5 - Create a markdown cell to list data science libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn

# %% [markdown]
# Exercise 6 - Create a markdown cell with a table of Data Science tools
#
# Create a single column table in this cell with the first row containing the header Data Science Tools
#
# | Data Science Tools     |
# |------------------------|
# | Jupyter Notebook        |
# | RStudio                |
# | Apache Zeppelin        |

# %% [markdown]
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples
#
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# Exercise 8 - Create a code cell to multiply and add numbers

# This is a simple arithmetic expression to multiply then add integers.
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# Exercise 9 - Create a code cell to convert minutes to hours

# This will convert 200 minutes to hours by dividing by 60.
hours = 200 / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# Exercise 10 - Insert a markdown cell to list Objectives
#
# **Objectives:**
#
# - List popular languages for Data Science.
# - Identify commonly used libraries in Data Science.
# - Understand data science tools and environments.
# - Evaluate arithmetic expressions in Python.
# - Convert time measurements from minutes to hours.

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Author's name
#
# ## Author
#
# Yakoob Naji
